# %%
import pathlib
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib nbagg
df = pd.read_csv('data/kaggle_toxicity/train.csv', error_bad_lines=False)
fig = plt.figure(figsize=(8,5))
ax = sns.barplot(x=df.toxic.unique(),y=df.toxic.value_counts());
ax.set(xlabel='Labels')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# all imports
from collections import Counter
import spacy
from tqdm import tqdm, tqdm_notebook, tnrange
tqdm.pandas(desc='Progress')

# load spacy tokenizer
nlp = spacy.load('en',disable=['parser', 'tagger', 'ner'])
# df.progress_apply is tqdm method for pandas. It shows progress bar for apply function
# remove the leading and trailing spaces
df['comment_text'] = df.comment_text.progress_apply(lambda x: x.strip())

# build vocabulary and corresponding counts
words = Counter()
for sent in tqdm(df.comment_text.values):
    words.update(w.text.lower() for w in nlp(sent))

# sort with most frequently occuring words first
words = sorted(words, key=words.get, reverse=True)
# add <pad> and <unk> token to vocab which will be used later
words = ['_PAD','_UNK'] + words

# create word to index dictionary and reverse
word2idx = {o:i for i,o in enumerate(words)}
idx2word = {i:o for i,o in enumerate(words)}

def indexer(s): 
    return [word2idx[w.text.lower()] for w in nlp(s)]

# tokenize the tweets and calculate lengths
df['sentimentidx'] = df.SentimentText.progress_apply(indexer)
df['lengths'] = df.sentimentidx.progress_apply(len)

fig = plt.figure(figsize=(8,5))
ax = sns.distplot(df.lengths.values,kde=False);
ax.set(xlabel='Tweet Length', ylabel='Frequency')
# Out:
# Progress: 100%|██████████| 159571/159571 [00:00<00:00, 524506.17it/s]
#   0%|          | 0/159571 [00:00<?, ?it/s]Exception KeyError: KeyError(<weakref at 0x10e189cb0; to 'tqdm' at 0x10d4c9710>,) in <bound method tqdm.__del__ of   0%|          | 0/159571 [00:00<?, ?it/s]> ignored
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-c5824f666d8e> in <module>()
#      14 words = Counter()
#      15 for sent in tqdm(df.comment_text.values):
# ---> 16     words.update(w.text.lower() for w in nlp(sent))
#      17
#      18 # sort with most frequently occuring words first
#
# /usr/local/lib/python2.7/site-packages/spacy/language.pyc in __call__(self, text, disable)
#     344             raise ValueError(Errors.E088.format(length=len(text),
#     345                                                 max_length=self.max_length))
# --> 346         doc = self.make_doc(text)
#     347         for name, proc in self.pipeline:
#     348             if name in disable:
#
# /usr/local/lib/python2.7/site-packages/spacy/language.pyc in make_doc(self, text)
#     376
#     377     def make_doc(self, text):
# --> 378         return self.tokenizer(text)
#     379
#     380     def update(self, docs, golds, drop=0., sgd=None, losses=None):
#
# TypeError: Argument 'string' has incorrect type (expected unicode, got str)
